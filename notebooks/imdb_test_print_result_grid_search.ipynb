# %% [markdown]
# ##### PLOTTER OF THE RESULTS OF A GRID SEARCH

# %%
import pickle
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
from scipy.stats import t

# %%
output_dir = "/home/zhanna/bachelorarbeit/zbb/experiments/output_grid_search_10_12_23"
output_dir = "/home/zhanna/bachelorarbeit/zbb/experiments/output_grid_search_final"
output_dir = "/home/zhanna/bachelorarbeit/zbb/experiments/output_grid_search_000"

model_names = [
    "RandomForestW2V",  # no
    "RandomForest",     # no
    "LogisticRegression", # ok
    "LogisticRegressionW2V",  # ok
    "NaiveSA",                  # ok   
    "AFinn",                    # ok
    "Vader", 
    "LSTM",
    "LSTM_W2V"
]

model_name = model_names[0]

# %%
import pandas as pd

import pandas as pd

def create_result_metrics(results_df):
    w2v_path="/data/zibaldone/projects/ai/zbb//data//datasets/googleW2v/word2vec-google-news-300.gz"
    try:
        metrics = ['accuracy', 'f1', 'recall', 'precision']
        metric = metrics[0]
        results_df = results_df.sort_values(by=["rank_test_{}".format(metric)])
    except:
        metrics = ['score']
        metric = metrics[0]
        results_df = results_df.sort_values(by=["rank_test_{}".format(metric)])
    if model_name.startswith("RandomForest"):
        print(model_name)
        results_df = results_df.set_index(results_df["params"].apply(
            lambda x: '{' + "_".join(
                str(val).replace(w2v_path, '')
                        .replace('5', '') 
                        .replace('reviews_no_stopwords', 'R.noS.') 
                        .replace('reviews_no_punctuation', 'R.noP.') 
                        .replace('stamm_no_punctuation', 'S.noP.') 
                        .replace('stamm_no_stop_punct', 'S.noS.P.') 
                        for val in x.values()) 
                       .replace('__', '') 
                       .replace('_1_', ',') 
                       .replace('_l2', '') 
                       .replace('y(', 'y, (') 
                       .replace('i(', 'i, (') 
                        + '}')
                        ).rename_axis("hyperparam")
    elif model_name.startswith("LogisticReg"):
        print(model_name)
        results_df = results_df.set_index(results_df["params"].apply(
            lambda x: '{' + ",".join([v.replace('_', '') for v in
                [str(val).replace(w2v_path, '')
                        .replace('None', '') 
                        .replace('True', '') 
                        .replace('l2', '') 
                        .replace('reviews_no_stopwords', 'R.noS.') 
                        .replace('reviews_no_punctuation', 'R.noP.') 
                        .replace('stamm_no_punctuation', 'S.noP.') 
                        .replace('stamm_no_stop_punct', 'S.noS.P.') 
                        for val in x.values()]])
        .replace(',,', '')
        .replace('_1_', ', ')
        .replace(',1,', ', ')
        .replace('.0', '.0, ') + '}'
                        )).rename_axis("hyperparam")
    elif model_name.startswith("Naive") or model_name.startswith("AFinn") or model_name.startswith("Vader"):
        print(model_name)
        results_df = results_df.set_index(results_df["params"].apply(
            lambda x: '{' + ",".join([v.replace('_', '') for v in
                [str(val).replace(w2v_path, '')
                        .replace('None', '') 
                        .replace('True', '') 
                        .replace('l2', '') 
                        .replace('reviews_no_stopwords', 'R.noS.') 
                        .replace('reviews_no_punctuation', 'R.noP.') 
                        .replace('stamm_no_punctuation', 'S.noP.') 
                        .replace('stamm_no_stop_punct', 'S.noS.P.') 
                        for val in x.values()]])
        .replace(',,', '')
        .replace('split,False,', '')
        .replace(',1,', ', ')
        .replace('.0', '.0, ') + '}'
                        )).rename_axis("hyperparam")
    else:
        print(model_name)
        results_df = results_df.set_index(results_df["params"].apply(
            lambda x: '{' + ",".join([v.replace('_', '') for v in
                [str(val).replace(w2v_path, '')
                        .replace('None', '') 
                        .replace('True', '') 
                        .replace('l2', '') 
                        .replace('reviews_no_stopwords', 'R.noS.') 
                        .replace('reviews_no_punctuation', 'R.noP.') 
                        .replace('stamm_no_punctuation', 'S.noP.') 
                        .replace('stamm_no_stop_punct', 'S.noS.P.') 
                        for val in x.values()]])
        .replace(',,', '')
        .replace('_1_', ', ')
        .replace(',1,', ', ')
        .replace('//data//datasets/googleW2v/word2vec-google-news-300.gz,softmax, /usr/src/myapp//data//datasets/allwords.csv', '') 
        .replace(',15relu,64,300,/usr/src/myapp', '') 
        .replace('.0', '.0, ') + '}'
                        )).rename_axis("hyperparam")
        # print(results_df.iloc[0])
    # results_df[["params", "rank_test_score", "mean_test_score", "std_test_score"]]
    columns = [
        "mean_test_{}",
        # "std_test_{}",
        ]
    projec = ['rank_test_{}'.format(metric)]
    for m in metrics:
        for c in columns:
            projec.append(c.format(m))
    results_df[
        ["rank_test_{}".format(metric), 
        "mean_test_{}".format(metric), 
        # "std_test_{}".format(metric)
        ]
        ]

    results_metrics = results_df[projec]
    list_columns = results_metrics.columns
    map_rename = {}
    for c in list_columns:
        map_rename[c] = '\\textbf{' + c.replace('rank_test_accuracy', 'rank').replace('_test_', ' ') + '}'
    # print(map_rename)

    results_metrics = results_metrics.rename(columns=map_rename)
    return results_metrics

# %%
model_names = [
    "RandomForestW2V",        # ko
    "RandomForest",           # ko
    "LogisticRegression",     # ok
    "LogisticRegressionW2V",  # ok
    "NaiveSA",                # ok   
    "AFinn",                  # ok
    "Vader", 
    "LSTM",
    "LSTM_W2V"
]

y_lims = [
    [0.76, 0.85],
    [0.83, 0.88],
    [0.87, 0.93],
    [0.8, 0.9],
    [0.4, 0.9],
    [0.6, 0.9],
    [0.6, 0.9],
    [0.8, 0.9],
    [0.8, 0.85],
]

def load_data(output_dir, model_name):
    file_name = os.path.join(output_dir, 'grid_search_{}_cv_results.pkl'.format(model_name))
    with open(file_name, 'rb') as f:
        results = pickle.load(f)
    results_df = pd.DataFrame(results)
    # results_df.columns
    return results_df



result_tables = ""
for model_name, y_lim, in zip(model_names, y_lims):
    try:
        output_dir = "/home/zhanna/bachelorarbeit/zbb/experiments/output_grid_search_000"
        df = load_data(output_dir, model_name)
    except Exception as e:
        print(" cannot load file for model ", model_name, ": ", str(e))
    print(" model", model_name)
    results_metrics = create_result_metrics(df)
    result_tables += "\\begin{table}[H]\n"
    result_tables += "\\centering\n"
    result_tables += results_metrics.to_latex()
    m = model_name.replace('_', '\_')
    result_tables += "\\caption[Metriken für das Modell {}]{{Metrik für Modell {}}}\n".format(m, m)
    result_tables += "\\end{table}\n\n"

print(result_tables)
# Out:
#  model RandomForestW2V
# RandomForestW2V
#  model RandomForest
# RandomForest
#  model LogisticRegression
# LogisticRegression
#  model LogisticRegressionW2V
# LogisticRegressionW2V
#  model NaiveSA
# NaiveSA
#  model AFinn
# AFinn
#  model Vader
# Vader
#  model LSTM
# LSTM
#  model LSTM_W2V
# LSTM_W2V
# \begin{table}[H]
# \centering
# \begin{tabular}{lrrrrr}
# \toprule
#  & \textbf{rank} & \textbf{mean accuracy} & \textbf{mean f1} & \textbf{mean recall} & \textbf{mean precision} \\
# hyperparam &  &  &  &  &  \\
# \midrule
# {R.noS.,entropy} & 1 & 0.818574 & 0.819207 & 0.822120 & 0.816364 \\
# {R.noP.,entropy} & 2 & 0.816508 & 0.816402 & 0.815976 & 0.816878 \\
# {R.noS.,gini} & 3 & 0.815810 & 0.817122 & 0.823032 & 0.811347 \\
# {R.noP.,gini} & 4 & 0.812930 & 0.813904 & 0.818192 & 0.809710 \\
# {S.noS.P.,entropy} & 5 & 0.778816 & 0.779461 & 0.781772 & 0.777217 \\
# {S.noS.P.,gini} & 6 & 0.774538 & 0.776061 & 0.781392 & 0.770853 \\
# \bottomrule
# \end{tabular}
# \caption[Metriken für das Modell RandomForestW2V]{Metrik für Modell RandomForestW2V}
# \end{table}
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lrrrrr}
# \toprule
#  & \textbf{rank} & \textbf{mean accuracy} & \textbf{mean f1} & \textbf{mean recall} & \textbf{mean precision} \\
# hyperparam &  &  &  &  &  \\
# \midrule
# {R.noS.,entropy, (1, 2)} & 1 & 0.865786 & 0.865007 & 0.860064 & 0.870065 \\
# {S.noS.P.,entropy, (1, 2)} & 2 & 0.862734 & 0.863104 & 0.865440 & 0.860828 \\
# {R.noS.,gini, (1, 2)} & 3 & 0.862524 & 0.861165 & 0.852796 & 0.869751 \\
# {R.noP.,entropy, (1, 2)} & 4 & 0.859830 & 0.859063 & 0.854428 & 0.863802 \\
# {S.noS.P.,gini, (1, 2)} & 5 & 0.859752 & 0.859684 & 0.859284 & 0.860139 \\
# {R.noS.,entropy, (1, 1)} & 6 & 0.859528 & 0.859699 & 0.860764 & 0.858690 \\
# {R.noS.,gini, (1, 1)} & 7 & 0.858424 & 0.857713 & 0.853464 & 0.862055 \\
# {R.noP.,gini, (1, 2)} & 8 & 0.856802 & 0.855251 & 0.846108 & 0.864652 \\
# {S.noS.P.,entropy, (1, 1)} & 9 & 0.855256 & 0.855761 & 0.858808 & 0.852788 \\
# {S.noS.P.,gini, (1, 1)} & 10 & 0.853102 & 0.852967 & 0.852240 & 0.853756 \\
# {R.noP.,entropy, (1, 1)} & 11 & 0.848388 & 0.848706 & 0.850508 & 0.846955 \\
# {R.noP.,gini, (1, 1)} & 12 & 0.845046 & 0.844314 & 0.840384 & 0.848336 \\
# \bottomrule
# \end{tabular}
# \caption[Metriken für das Modell RandomForest]{Metrik für Modell RandomForest}
# \end{table}
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lrrrrr}
# \toprule
#  & \textbf{rank} & \textbf{mean accuracy} & \textbf{mean f1} & \textbf{mean recall} & \textbf{mean precision} \\
# hyperparam &  &  &  &  &  \\
# \midrule
# {100.0, R.noP., (1, 2)} & 1 & 0.918800 & 0.919465 & 0.927032 & 0.912047 \\
# {100.0, R.noS., (1, 2)} & 2 & 0.910276 & 0.911364 & 0.922532 & 0.900489 \\
# {100.0, S.noS.P., (1, 2)} & 3 & 0.907270 & 0.908353 & 0.919068 & 0.897909 \\
# {1.0, R.noP., (1, 2)} & 4 & 0.900652 & 0.901838 & 0.912740 & 0.891220 \\
# {1.0, R.noS., (1, 1)} & 5 & 0.898062 & 0.899274 & 0.910088 & 0.888745 \\
# {1.0, R.noP., (1, 1)} & 6 & 0.897970 & 0.898923 & 0.907392 & 0.890636 \\
# {1.0, R.noS., (1, 2)} & 7 & 0.895266 & 0.896837 & 0.910488 & 0.883619 \\
# {100.0, R.noP., (1, 1)} & 8 & 0.894480 & 0.895065 & 0.900036 & 0.890177 \\
# {1.0, S.noS.P., (1, 1)} & 9 & 0.893510 & 0.894802 & 0.905776 & 0.884123 \\
# {1.0, S.noS.P., (1, 2)} & 10 & 0.892924 & 0.894627 & 0.909088 & 0.880649 \\
# {100.0, R.noS., (1, 1)} & 11 & 0.891146 & 0.891734 & 0.896560 & 0.886989 \\
# {100.0, S.noS.P., (1, 1)} & 12 & 0.884852 & 0.885550 & 0.890964 & 0.880235 \\
# \bottomrule
# \end{tabular}
# \caption[Metriken für das Modell LogisticRegression]{Metrik für Modell LogisticRegression}
# \end{table}
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lrrrrr}
# \toprule
#  & \textbf{rank} & \textbf{mean accuracy} & \textbf{mean f1} & \textbf{mean recall} & \textbf{mean precision} \\
# hyperparam &  &  &  &  &  \\
# \midrule
# {100.0, R.noP.,11} & 1 & 0.859494 & 0.859634 & 0.860488 & 0.858791 \\
# {100.0, R.noS.,11} & 2 & 0.858138 & 0.858538 & 0.860968 & 0.856133 \\
# {1.0, R.noS.,11} & 3 & 0.854078 & 0.854269 & 0.855396 & 0.853151 \\
# {1.0, R.noP.,11} & 4 & 0.848030 & 0.847419 & 0.844032 & 0.850841 \\
# {100.0, S.noS.P.,11} & 5 & 0.817050 & 0.817921 & 0.821856 & 0.814048 \\
# {1.0, S.noS.P.,11} & 6 & 0.813556 & 0.814241 & 0.817280 & 0.811249 \\
# \bottomrule
# \end{tabular}
# \caption[Metriken für das Modell LogisticRegressionW2V]{Metrik für Modell LogisticRegressionW2V}
# \end{table}
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lrrrrr}
# \toprule
#  & \textbf{rank} & \textbf{mean accuracy} & \textbf{mean f1} & \textbf{mean recall} & \textbf{mean precision} \\
# hyperparam &  &  &  &  &  \\
# \midrule
# {R.noS., 1,2.0, } & 1 & 0.855758 & 0.853264 & 0.838808 & 0.868286 \\
# {R.noP., 1,2.0, } & 2 & 0.854322 & 0.849637 & 0.823232 & 0.877856 \\
# {S.noS.P., 1,2.0, } & 3 & 0.840468 & 0.832169 & 0.791112 & 0.877804 \\
# {R.noS., 1,0.0, } & 4 & 0.696560 & 0.640858 & 0.541560 & 0.784921 \\
# {R.noP., 1,0.0, } & 5 & 0.678460 & 0.586284 & 0.455760 & 0.821831 \\
# {S.noS.P., 1,0.0, } & 6 & 0.641120 & 0.535543 & 0.413880 & 0.758729 \\
# \bottomrule
# \end{tabular}
# \caption[Metriken für das Modell NaiveSA]{Metrik für Modell NaiveSA}
# \end{table}
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lrrrrr}
# \toprule
#  & \textbf{rank} & \textbf{mean accuracy} & \textbf{mean f1} & \textbf{mean recall} & \textbf{mean precision} \\
# hyperparam &  &  &  &  &  \\
# \midrule
# {R.noP.,1} & 1 & 0.712580 & 0.746037 & 0.844320 & 0.668250 \\
# {R.noS.,1} & 2 & 0.703740 & 0.741524 & 0.849920 & 0.657650 \\
# {S.noS.P.,1} & 3 & 0.665520 & 0.709390 & 0.816480 & 0.627135 \\
# \bottomrule
# \end{tabular}
# \caption[Metriken für das Modell AFinn]{Metrik für Modell AFinn}
# \end{table}
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lrrrrr}
# \toprule
#  & \textbf{rank} & \textbf{mean accuracy} & \textbf{mean f1} & \textbf{mean recall} & \textbf{mean precision} \\
# hyperparam &  &  &  &  &  \\
# \midrule
# {R.noP.,1} & 1 & 0.696560 & 0.737944 & 0.854480 & 0.649380 \\
# {R.noS.,1} & 2 & 0.673560 & 0.726755 & 0.868240 & 0.624921 \\
# {S.noS.P.,1} & 3 & 0.650140 & 0.703714 & 0.830960 & 0.610264 \\
# \bottomrule
# \end{tabular}
# \caption[Metriken für das Modell Vader]{Metrik für Modell Vader}
# \end{table}
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lrrrrr}
# \toprule
#  & \textbf{rank} & \textbf{mean accuracy} & \textbf{mean f1} & \textbf{mean recall} & \textbf{mean precision} \\
# hyperparam &  &  &  &  &  \\
# \midrule
# {S.noS.P., 5, 1000} & 1 & 0.858546 & 0.858800 & 0.861624 & 0.858116 \\
# {R.noP., 5, 1000} & 2 & 0.858330 & 0.859849 & 0.869468 & 0.852811 \\
# {R.noS., 5, 1000} & 3 & 0.858236 & 0.859225 & 0.866352 & 0.853669 \\
# {S.noS.P., 5, 500} & 4 & 0.843704 & 0.843736 & 0.845160 & 0.843880 \\
# {R.noS., 5, 500} & 5 & 0.837368 & 0.837441 & 0.839124 & 0.837725 \\
# {R.noP., 5, 500} & 6 & 0.829594 & 0.835485 & 0.864980 & 0.812496 \\
# \bottomrule
# \end{tabular}
# \caption[Metriken für das Modell LSTM]{Metrik für Modell LSTM}
# \end{table}
#
# \begin{table}[H]
# \centering
# \begin{tabular}{lrrrrr}
# \toprule
#  & \textbf{rank} & \textbf{mean accuracy} & \textbf{mean f1} & \textbf{mean recall} & \textbf{mean precision} \\
# hyperparam &  &  &  &  &  \\
# \midrule
# {S.noS.P.} & 1 & 0.822400 & 0.821506 & 0.820600 & 0.827364 \\
# {R.noS.} & 2 & 0.819440 & 0.819556 & 0.820460 & 0.819618 \\
# {R.noP.} & 3 & 0.808190 & 0.810798 & 0.825740 & 0.803078 \\
# \bottomrule
# \end{tabular}
# \caption[Metriken für das Modell LSTM\_W2V]{Metrik für Modell LSTM\_W2V}
# \end{table}

# %%
# Out:
#    a
# 0  1
# 1  2
# 2  3
